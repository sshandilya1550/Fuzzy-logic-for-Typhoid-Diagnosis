# %%
import numpy as npy
import pandas as pd

# %%
df=pd.DataFrame({'FVR':npy.random.randint(96,104,50),
                'HDE':npy.random.randint(1,11,50),
                'NAU':npy.random.randint(1,11,50),
                'VOM':npy.random.randint(1,11,50),
                'JDE':npy.random.randint(1,11,50),
                'JPN':npy.random.randint(1,11,50),
                'BWS':npy.random.randint(1,11,50),
                'DZS':npy.random.randint(1,11,50),
                'LAE':npy.random.randint(1,11,50)})
print(df)
# Out:
#     FVR  HDE  NAU  VOM  JDE  JPN  BWS  DZS  LAE
# 0    99    9    4    3    5    4    7    6    4
# 1    97   10    7    4    3    4   10    7    7
# 2   101    3    6    9   10    3    5    9    1
# 3   102    5   10    2   10    3    2    7    1
# 4    98    9   10    4   10    5    7    9   10
# 5    96    3    4    9    4    8    2    4    8
# 6    96   10    2    4    3    6    8    4    2
# 7    97    8    3    8    7    7    8    8    1
# 8    97    9    5    5    3    6    2    9    6
# 9    97    1    8    7    7    2    2    8    9
# 10   98    7    1    4    9    3    7   10   10
# 11   97    6    8    6    9    8    7    1    6
# 12   96    7    7    4    5    2    7    7    5
# 13   96    2    3    9    3    7    8    6    2
# 14   97    2    3    1    7    9    4    5   10
# 15  103    7    9    4    7   10    7    3    2
# 16   96    9   10    9    7    8   10    6    8
# 17  102    9    4    4    3    8    7    8    8
# 18  102    5    5   10    7    9    3    6    1
# ...

# %%
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

# %%
Fever=ctrl.Antecedent(np.arange(96,104,1),'Fever')
Fever['mild']=fuzzy.trimf(Fever.universe,[96,96,97.5])
Fever['moderate']=fuzzy.trimf(Fever.universe,[97,98,99])
Fever['severe']=fuzzy.trimf(Fever.universe,[98.5,100,101])
Fever['very_severe']=fuzzy.trapmf(Fever.universe,[100.5,102,103,103])
Fever.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Headache=ctrl.Antecedent(np.arange(1,11,1),'Headache')
Headache['mild']=fuzzy.trimf(Headache.universe,[1,1,3])
Headache['moderate']=fuzzy.trapmf(Headache.universe,[2,3,4,5])
Headache['severe']=fuzzy.trapmf(Headache.universe,[4,6,7,8])
Headache['very_severe']=fuzzy.trapmf(Headache.universe,[7,9,10,10])
Headache.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Nausea=ctrl.Antecedent(np.arange(1,11,1),'Nausea')
Nausea['mild']=fuzzy.trimf(Nausea.universe,[1,1,3])
Nausea['moderate']=fuzzy.trapmf(Nausea.universe,[2,3,4,5])
Nausea['severe']=fuzzy.trapmf(Nausea.universe,[4,6,7,8])
Nausea['very_severe']=fuzzy.trapmf(Nausea.universe,[7,9,10,10])
Nausea.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Vomiting=ctrl.Antecedent(np.arange(1,11,1),'Vomiting')
Vomiting['mild']=fuzzy.trimf(Vomiting.universe,[1,1,3])
Vomiting['moderate']=fuzzy.trapmf(Vomiting.universe,[2,3,4,5])
Vomiting['severe']=fuzzy.trapmf(Vomiting.universe,[4,6,7,8])
Vomiting['very_severe']=fuzzy.trapmf(Vomiting.universe,[7,9,10,10])
Vomiting.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Jaundice=ctrl.Antecedent(np.arange(1,11,1),'Jaundice')
Jaundice['mild']=fuzzy.trimf(Jaundice.universe,[1,1,3])
Jaundice['moderate']=fuzzy.trapmf(Jaundice.universe,[2,3,4,5])
Jaundice['severe']=fuzzy.trapmf(Jaundice.universe,[4,6,7,8])
Jaundice['very_severe']=fuzzy.trapmf(Jaundice.universe,[7,9,10,10])
Jaundice.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Jointpain=ctrl.Antecedent(np.arange(1,11,1),'Jointpain')
Jointpain['mild']=fuzzy.trimf(Jointpain.universe,[1,1,3])
Jointpain['moderate']=fuzzy.trapmf(Jointpain.universe,[2,3,4,5])
Jointpain['severe']=fuzzy.trapmf(Jointpain.universe,[4,6,7,8])
Jointpain['very_severe']=fuzzy.trapmf(Jointpain.universe,[7,9,10,10])
Jointpain.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Bodyweak=ctrl.Antecedent(np.arange(1,11,1),'Bodyweak')
Bodyweak['mild']=fuzzy.trimf(Bodyweak.universe,[1,1,3])
Bodyweak['moderate']=fuzzy.trapmf(Bodyweak.universe,[2,3,4,5])
Bodyweak['severe']=fuzzy.trapmf(Bodyweak.universe,[4,6,7,8])
Bodyweak['very_severe']=fuzzy.trapmf(Bodyweak.universe,[7,9,10,10])
Bodyweak.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Dizziness=ctrl.Antecedent(np.arange(1,11,1),'Dizziness')
Dizziness['mild']=fuzzy.trimf(Dizziness.universe,[1,1,3])
Dizziness['moderate']=fuzzy.trapmf(Dizziness.universe,[2,3,4,5])
Dizziness['severe']=fuzzy.trapmf(Dizziness.universe,[4,6,7,8])
Dizziness['very_severe']=fuzzy.trapmf(Dizziness.universe,[7,9,10,10])
Dizziness.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
Lossappetite=ctrl.Antecedent(np.arange(1,11,1),'Lossappetite')
Lossappetite['mild']=fuzzy.trimf(Lossappetite.universe,[1,1,3])
Lossappetite['moderate']=fuzzy.trapmf(Lossappetite.universe,[2,3,4,5])
Lossappetite['severe']=fuzzy.trapmf(Lossappetite.universe,[4,6,7,8])
Lossappetite['very_severe']=fuzzy.trapmf(Lossappetite.universe,[7,9,10,10])
Lossappetite.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
typhoid=ctrl.Consequent(np.arange(0,21),'typhoid')
typhoid.automf(5)
typhoid.view()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule2=ctrl.Rule(Fever['moderate'] & Headache['moderate']& Nausea['moderate']&Vomiting['moderate'] & Jaundice['moderate']& Jointpain['moderate']&Bodyweak['moderate'] & Dizziness['moderate']& Lossappetite['moderate'],typhoid['mediocre'])
rule3=ctrl.Rule(Fever['severe'] & Headache['severe']& Nausea['severe']&Vomiting['severe'] & Jaundice['severe']& Jointpain['severe']&Bodyweak['severe'] & Dizziness['severe']& Lossappetite['severe'],typhoid['decent'])
rule4=ctrl.Rule(Fever['very_severe'] & Headache['very_severe']& Nausea['very_severe']&Vomiting['very_severe'] & Jaundice['very_severe']& Jointpain['very_severe']&Bodyweak['very_severe'] & Dizziness['very_severe']& Lossappetite['very_severe'],typhoid['good'])
rule5=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['moderate'],typhoid['poor'])
rule6=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['moderate']& Lossappetite['mild'],typhoid['poor'])
rule7=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['moderate'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule8=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['moderate']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule9=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['moderate']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule10=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['moderate'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule11=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['moderate']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule12=ctrl.Rule(Fever['mild'] & Headache['moderate']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule13=ctrl.Rule(Fever['moderate'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule14=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['moderate']& Lossappetite['moderate'],typhoid['poor'])
rule15=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['moderate'] & Dizziness['moderate']& Lossappetite['mild'],typhoid['poor'])
rule16=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['moderate']&Bodyweak['moderate'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule17=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['mild'] & Jaundice['moderate']& Jointpain['moderate']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule18=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['mild']&Vomiting['moderate'] & Jaundice['moderate']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule19=ctrl.Rule(Fever['mild'] & Headache['mild']& Nausea['moderate']&Vomiting['moderate'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule20=ctrl.Rule(Fever['mild'] & Headache['moderate']& Nausea['moderate']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])
rule21=ctrl.Rule(Fever['moderate'] & Headache['moderate']& Nausea['mild']&Vomiting['mild'] & Jaundice['mild']& Jointpain['mild']&Bodyweak['mild'] & Dizziness['mild']& Lossappetite['mild'],typhoid['poor'])


rule=[rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21]

# %%
x=ctrl.ControlSystem(rule)
y=ctrl.ControlSystemSimulation(x)

# %%
y.input['Fever']=96
y.input['Headache']=1
y.input['Nausea']=1
y.input['Vomiting']=1
y.input['Jaundice']=1
y.input['Jointpain']=1
y.input['Bodyweak']=1
y.input['Dizziness']=1
y.input['Lossappetite']=1
y.compute()
print(y.output['typhoid'])
# Out:
# 1.6666666666666665
